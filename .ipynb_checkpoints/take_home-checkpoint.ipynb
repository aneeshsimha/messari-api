# %%
import os
import pandas as pd
from pandas import json_normalize
import numpy as np
import requests
import time
import json

from functools import reduce

# %%
messari_TS_url = "hello"
messari_MP_url =  "hi"
messari_yfi_url = "https://data.messari.io/api/v1/assets/yfi/metrics/price/time-series?start=2021-01-01&end=2021-02-01&interval=1d"
response = requests.get(messari_yfi_url)
print(response.status_code)
data = response.json()
dumps = json.dumps(data, sort_keys=True, indent=4)
# Out:
# 200

# %%
info = json.loads(dumps)
print(info['data']['symbol'])
df2 =json_normalize(info['data'], record_path = ['values'])
df2.columns = ["timestamp","open","high", "low", "close", "volume"]
df2['timestamp']=df2.apply(lambda x: time.strftime('%Y-%m-%d', time.gmtime(x['timestamp']/1000)),axis=1)

yfi = df2[['timestamp','close']]
yfi.columns = ['timestamp','yfi']
yfi = yfi.set_index('timestamp')

print(yfi.head())
# Out:
# YFI
#                      yfi
# timestamp
# 2021-01-01  21898.581377
# 2021-01-02  21467.056191
# 2021-01-03  23903.585935
# 2021-01-04  23391.127028
# 2021-01-05  23810.774761

# %%
messari_uni_url = "https://data.messari.io/api/v1/assets/uni/metrics/price/time-series?start=2021-01-01&end=2021-02-01&interval=1d"
response2 = requests.get(messari_uni_url)
print(response2.status_code)
data2 = response2.json()
dumps2 = json.dumps(data2, sort_keys=True, indent=4)
info2 = json.loads(dumps2)
#print(info2)
df22 =json_normalize(info2['data'], record_path = ['values'])
df22.columns = ["timestamp","open","high", "low", "close", "volume"]
df22['timestamp']=df22.apply(lambda x: time.strftime('%Y-%m-%d', time.gmtime(x['timestamp']/1000)),axis=1)

uni = df22[['timestamp','close']]
uni.columns = ['timestamp','uni']
uni = uni.set_index('timestamp')
#print(uni.head())
# Out:
# 200
# {'data': {'_internal_temp_agora_id': 'd32b98a8-7160-480b-a331-fa294aa25301', 'contract_addresses': [{'contract_address': '0x1f9840a85d5af5bf1d1762f925bdaddc4201f984', 'platform': 'ethereum'}], 'id': '1d51479d-68f6-4886-8644-2a55ea9007bf', 'name': 'Uniswap', 'parameters': {'asset_id': '1d51479d-68f6-4886-8644-2a55ea9007bf', 'asset_key': 'uni', 'columns': ['timestamp', 'open', 'high', 'low', 'close', 'volume'], 'end': '2021-02-01T00:00:00Z', 'format': 'json', 'interval': '1d', 'order': 'ascending', 'start': '2021-01-01T00:00:00Z', 'timestamp_format': 'unix-milliseconds'}, 'schema': {'description': 'Volume weighted average price computed using Messari Methodology', 'metric_id': 'price', 'minimum_interval': '1m', 'name': 'Price', 'source_attribution': [{'name': 'Kaiko', 'url': 'https://www.kaiko.com/'}], 'values_schema': {'close': 'The price of the asset at the end of the specified interval in US dollars.', 'high': 'The highest price of the asset during the specified interval in US dollars.', 'low': 'The lowest price of the asset during the specified interval in US dollars', 'open': 'The price of the asset at the beginning of the specified interval in US dollars.', 'timestamp': 'Timestamp in milliseconds since the epoch (1 January 1970 00:00:00 UTC)', 'volume': 'The total volume traded during the specified interval across all Messari method markets in US dollars'}}, 'slug': 'uniswap', 'symbol': 'UNI', 'values': [[1609459200000, 5.155478598798689, 5.296846153582423, 4.6152346751221565, 4.746491040329197, 406145494.77693987], [1609545600000, 4.748944315744445, 5.186366717009682, 4.49084791606898, 4.859523433554639, 363529640.1231304], [1609632000000, 4.859510630707039, 5.649366915931066, 4.680394413561484, 5.520508084584113, 429101686.66688204], [1609718400000, 5.529420364540726, 6.2348293062946505, 4.857096068084248, 5.425184600765289, 545836803.7648592], [1609804800000, 5.4008956518861675, 6.575656448587438, 5.189169016263081, 6.271045859453688, 440757547.89688563], [1609891200000, 6.276290740184734, 6.619043871988623, 6.021354519744939, 6.427416942630984, 298367302.4730226], [1609977600000, 6.430649288425772, 6.831946116883024, 5.902719087391224, 6.264812888548188, 294906402.9325545], [1610064000000, 6.266867749929113, 6.407122802816703, 5.447224523052808, 5.883651568852962, 287537790.97216374], [1610150400000, 5.876752716863734, 6.369207246875991, 5.66834677139211, 6.248684823799602, 211890852.79939643], [1610236800000, 6.276469769090952, 6.608679496628027, 5.50469092009066, 5.983116773987399, 259949303.82116345], [1610323200000, 5.9886301423389146, 5.99969652436936, 4.394917024357386, 5.244628679424875, 409960882.7310083], [1610409600000, 5.250152712670282, 5.836784402348345, 4.959241213099554, 5.5863243489766745, 225276603.2612416], [1610496000000, 5.585497202900989, 6.391977861216827, 5.255684341581696, 6.339275514340326, 221417335.56296894], [1610582400000, 6.343591375619123, 7.1414, 6.18133451523662, 6.945319875801469, 349970370.01119727], [1610668800000, 6.942387685804482, 7.485634631781549, 6.371092359040603, 7.3721074291454345, 618545496.1892774], [1610755200000, 7.387134685559088, 9.393251473785648, 7.188563864939689, 8.397765714602508, 868817701.0192279], [1610841600000, 8.368272524983455, 9.209797339697726, 8.057904925886369, 8.681501695359712, 658834719.8693262], [1610928000000, 8.690080161017956, 9.884853403964298, 8.301534609659631, 9.192614169961717, 531363606.29584885], [1611014400000, 9.195799289622752, 9.710751293566071, 8.461, 8.597245709280644, 448234854.6554653], [1611100800000, 8.623609047211483, 9.050035299351274, 7.6347856235210605, 8.978146455592164, 407319600.82762134], [1611187200000, 8.97658342438784, 9.578647361444046, 7.3025553183984, 7.580083789452261, 497277858.22463393], [1611273600000, 7.577680997914951, 9.038668683261527, 7.036401155880369, 8.69615037065737, 322948100.091204], [1611360000000, 8.71448465965425, 9.541307692045029, 8.511930538107572, 9.346475554525398, 281371772.86922336], [161144 ...

# %%
#print(https://data.messari.io/api/v1/assets/metrics)
messari_test_url = "https://data.messari.io/api/v1/assets/metrics"
response1 = requests.get(messari_test_url)
data1 = response1.json()
dumps1 = json.dumps(data1, sort_keys=True, indent=4)
print(dumps1)
# Out:
# {
#     "data": {
#         "metrics": [
#             {
#                 "description": "The percentage of miner revenue derived from creating and including uncle blocks in that interval. This is equal to the sum of the uncle inclusion reward (for the main chain block miner) and the uncle rewards (for the uncle block miners) divided by the miner revenue.",
#                 "metric_id": "blk.unc.rew.pct",
#                 "minimum_interval": "1d",
#                 "name": "Block Uncle Rewards Percent",
#                 "role_restriction": [
#                     "pro",
#                     "enterprise"
#                 ],
#                 "source_attribution": [
#                     {
#                         "name": "Coinmetrics",
#                         "url": "https://coinmetrics.io"
#                     }
#                 ],
#                 "values_schema": {
#                     "block_uncle_rewards_percent": "The percentage of miner revenue derived from creating and including uncle blocks in that interval. This is equal to the sum of the uncle inclusion reward (for the main chain block miner) and the uncle rewards (for the uncle block miners) divided by the miner revenue."
#                 }
#             },
#             {
#                 "description": "The sum in US dollars withdrawn from Binance that interval.",
#                 "metric_id": "exch.binance.flow.out",
#                 "minimum_interval": "1d",
#                 "name": "Exchange Flow Out Binance (USD)",
#                 "role_restriction": [
#                     "pro",
#                     "enterprise"
#                 ],
#                 "source_attribution": [
#                     {
#                         "name": "Coinmetrics",
#                         "url": "https://coinmetrics.io"
#                     }
#                 ],
#                 "values_schema": {
#                     "exchange_flow_out_binance_usd": "The sum in native units withdrawn from Binance that interval."
#                 }
#             },
#             {
#                 "description": "The percentage of new native units (continuous) issued over that interval divided by the current supply at the end of that interval. Also referred to as the daily inflation rate.",
#                 "metric_id": "iss.rate.day",
#                 "minimum_interval": "1d",
#                 "name": "Issuance Rate Daily",
#                 "role_restriction": [
#                     "pro",
#                     "enterprise"
#                 ],
#                 "source_attribution": [
#                     {
#                         "name": "Coinmetrics",
#                         "url": "https://coinmetrics.io"
#                     }
#                 ],
#                 "values_schema": {
#                     "issuance_rate_daily": "The percentage of new native units (continuous) issued over that interval divided by the current supply at the end of that interval. Also referred to as the daily inflation rate."
#                 }
#             },
#             {
#                 "description": "The sum of the balances of all addresses within one hop of a mining entity in USD. An address within one hop of a mining entity is defined as an address that has been credited from a transaction debiting the 'FEES' or 'ISSUANCE' accounts, or any address that has been credited in a transaction sent by such an address.",
#                 "metric_id": "miner.1hop.sply",
#                 "minimum_interval": "1d",
#                 "name": "Miner 1 Hop Supply USD",
#                 "role_restriction": [
#                     "pro",
#                     "enterprise"
#                 ],
#                 "source_attribution": [
#                     {
#                         "name": "Coinmetrics",
#                         "url": "https://coinmetrics.io"
#                     }
#                 ],
#                 "values_schema": {
#                     "miner_supply_1hop_usd": "The sum of the balances of all addresses within one hop of a mining entity in USD. An address within one hop of a mining entity is defined as an address that has been credited from a transaction debiting the 'FEES' or 'ISSUANCE' accounts, or any address that has been credited in a transaction sent by such an address."
#                 }
#             },
#             {
#                 "description": "The sum USD value held by Bitstamp at the end of that interval.",
#                 "metric_id": "exch.sply.bitstamp",
#                 "minimum_interval": "1d",
#                 "name": "Exchange Supply Bitstamp (USD)",
#                 "role_restriction": [
#                     "pro",
#                     "enterprise"
#                 ],
#                 "source_attribution": [
#                     {
#                         "name": "Coinmetrics",
#                         "url": "https://coinmetrics.io"
#                     }
#                 ],
#                 "values_schema": {
#                     "exchange_supply_bitstamp_usd": "The sum USD value held by Bitstamp at the end of that interval."
#                 }
#             },
#             {
#                 "description": "The sum USD value sent to exchanges that interval, excluding exchange to exchange activity.",
#                 "metric_id": "exch.flow.in.usd",
#                 "minimum_interval": "1d",
#                 "name": "Exchange Flow In (USD)",
#                 "source_attribution": [
#                     {
#                         "name": "Coinmetrics",
#                         "url": "https://coinmetrics.io"
#                     }
#                 ],
#                 "values_schema": {
#                     "flow_in_usd": "The sum USD value sent to exchanges that interval, excluding exchange to exchange activity."
#                 }
#             },
#             {
#                 "description": "The percentage of the current supply that has been active in the trailing 1 year up to the end of that interval.",
#                 "metric_id": "sply.act.pct.1y",
#                 "minimum_interval": "1d",
#                 "name": "1 Year Active Supply Percentage",
#                 "role_restriction": [
#                     "pro",
#                     "enterprise"
#                 ],
#                 "source_attribution": [
#                     {
#                         "name": "Coinmetrics",
#                         "url": "https://coinmetrics.io"
#                     }
#                 ],
#                 "values_schema": {
#                     "supply_active_1y_percent": "The percentage of the current supply that has been active in the trailing 1 year up to the end of that interval."
#                 }
#             },
#             {
#                 "description": "The sum count of unique addresses holding at least ten million dollars' worth of native units as of the end of that interval. Only native units are considered (e.g., an address with less than X ETH but with more than X in ERC-20 tokens would not be considered).",
#                 "metric_id": "addr.bal.10m.cnt",
#                 "minimum_interval": "1d",
#                 "name": "Address Count (Bal > $10M USD)",
#                 "role_restriction": [
#                     "pro",
#                     "enterprise"
#                 ],
#                 "source_attribution": [
#                     {
#                         "name": "Coinmetrics",
#                         "url": "https://coinmetrics.io"
#                     }
#                 ],
#                 "values_schema": {
#                     "addresses": "The sum count of unique addresses holding at least ten million dollars' worth of native units as of the end of that interval. Only native units are considered (e.g., an address with less than X ETH but with more than X in ERC-20 tokens would not be considered)."
#                 }
#             },
#             {
#                 "description": "The sum USD value of all new native units issued that interval.",
#                 "metric_id": "sply.total.iss",
#                 "minimum_interval": "1d",
#                 "name": "Issuance Total (USD)",
#                 "source_attribution": [
#                     {
#                         "name": "Coinmetrics",
#                         "url": "https://coinmetrics.io"
#                     }
#                 ],
#                 "values_schema": {
#                     "issuance_total_usd": "The sum USD value of all new native units issued that interval."
#                 }
#             },
#             {
#                 "description": "The sum count of unique addresses that were active in the network (as a recipient of a ledger change) that interval.",
#                 "metric_id": "addr.act.rcv.cnt",
#                 "minimum_interval": "1d",
#                 "name": "Active Receiving Address Count",
#                 "role_restriction": [
#                     "pro",
#                     "enterprise"
#                 ],
#                 "source_attribution": [
#                     {
#                         "name": "Coinmetrics",
#                         "url": "https://coinmetrics.io"
#                     }
#                 ],
#                 "values_schema": {
#                     "addresses": "The sum count of unique addresses that were active in the network (as a recipient of a ledger change) that interval."
#                 }
#             },
#             {
#                 "description": "The sum count of unique addresses that were active in the network (as an originator of a ledger change) that interval.",
#                 "metric_id": "addr.act.sent.cnt",
#                 "minimum_interval": "1d",
#                 "name": "Active Sending Address Count",
#                 "role_restriction": [
#                     "pro",
#                     "enterprise"
#                 ],
#                 "source_attribution": [
#                     {
#                         "name": "Coinmetrics",
#                         "url": "https://coinmetrics.io"
#                     }
#                 ],
#                 "values_schema": {
#                     "addresses": "The sum count of unique addresses that were active in the network (as an originator of a ledger change) that interval."
#                 }
#             },
#             {
#                 "description": "The sum USD value sent to Gemini that interval.",
#                 "metric_id": "exch.gemini.flow.in",
#                 "minimum_interval": "1d",
#                 "name": "Exchange Flow In Gemini (USD)",
#                 "role_restriction": [
#                     "pro",
#                     "enterprise"
#                 ],
#                 "source_attribution": [
#                     {
#                         "name": "Coinmetrics",
#                         "url": "https://coinmetrics.io"
#                     }
#                 ],
#                 "values_schema": {
#                     "exchange_flow_in_gemini_usd": "The sum USD value sent to Gemini that interval."
#                 }
#             },
#             {
#                 "description": "The sum USD value withdrawn from exchanges that interval, including exchange to exchange activity.",
#                 "metric_id": "exch.flow.out.usd.incl",
#                 "minimum_interval": "1d",
#                 "name": "Exchange Flow Out Inclusive (USD)",
#                 "source_attribution": [
#                     {
#                         "name": "Coinmetrics",
#                         "url": "https://coinmetrics.io"
#                     }
#                 ],
#                 "values_schema": {
#                     "flow_out_usd": "The sum USD value withdrawn from exchanges that interval, including exchange to exchange activity."
#                 }
#             },
#             {
#                 "description": "The sum of unique native units that transacted at least once in the trailing 1 year up to the end of that interval. Native units that transacted more than once are only counted once.",
#                 "metric_id": "sply.act.1y",
#                 "minimum_interval": "1d",
#                 "name": "1 Year Active Supply",
#                 "role_restriction": [
#                     "pro",
#                     "enterprise"
#                 ],
#                 "source_attribution": [
#                     {
#                         "name": "Coinmetrics",
#                         "url": "https://coinmetrics.io"
#                     }
#                 ],
#                 "values_schema": {
#                     "supply_active_1y": "The sum of unique native units that transacted at least once in the trailing 1 year up to the end of that interval. Native units that transacted more than once are only counted once."
#                 }
#             },
#             {
#                 "description": "The sum of all native units being held in addresses whose balance was $10M or greater at the end of that interval. Only native units are considered (e.g., an address with less than X ETH but with more than X in ERC-20 tokens would not be considered).",
#                 "metric_id": "sply.addr.bal.10m",
#                 "minimum_interval": "1d",
#                 "name": "Supply from Addresses With Balance Above 10M USD",
#                 "role_restriction": [
#                     "pro",
#                     "enterprise"
#                 ],
#                 "source_attribution": [
#                     {
#                         "name": "Coinmetrics",
#                         "url": "https://coinmetrics.io"
#                     }
#                 ],
#                 "values_schema": {
#                     "supply_in_addr_above_bal_10m_usd": "The sum of all native units being held in addresses whose balance was $10M or greater at the end of that interval. Only native units are considered (e.g., an address with less than X ETH but with more than X in ERC-20 tokens would not be considered)."
#                 }
#             },
#             {
#                 "description": "The value-weighted average age in full days of all unspent transaction outputs.",
#                 "metric_id": "utxo.age.val.avg",
#                 "minimum_interval": "1d",
#                 "name": "UTXO Value Weighted Average Age",
#                 "role_restriction": [
#                     "pro",
#                     "enterprise"
#                 ],
#                 "source_attribution": [
#                     {
#                         "name": "Coinmetrics",
#                         "url": "https://coinmetrics.io"
#                     }
#                 ],
#                 "values_schema": {
#                     "utxo_age_value_weighted_avg": "The value-weighted average age in full days of all unspent transaction outputs."
#                 }
#             },
#             {
#                 "description": "The sum in native units sent to Poloniex that interval.",
#                 "metric_id": "exch.poloniex.flow.in.ntv",
#                 "minimum_interval": "1d",
#                 "name": "Exchange Flow In Poloniex (Native Units)",
#                 "role_restriction": [
#                     "pro",
#                     "enterprise"
#                 ],
#                 "source_attribution": [
#                     {
#                         "name": "Coinmetrics",
#                         "url": "https://coinmetrics.io"
#                     }
#                 ],
#                 "values_schema": {
#                     "exchange_flow_in_poloniex": "The sum in native units sent to Poloniex that interval."
#                 }
#             },
#             {
#                 "description": "The sum of all new native units issued that interval.",
#                 "metric_id": "sply.total.iss.ntv",
#                 "minimum_interval": "1d",
#                 "name": "Issuance Total (Native Units)",
#                 "source_attribution": [
#                     {
#                         "name": "Coinmetrics",
#                         "url": "https://coinmetrics.io"
#                     }
#                 ],
#                 "values_schema": {
#                     "issuance_total": "The sum of all new native units issued that interval."
#                 }
#             },
#             {
#                 "description": "The sum USD value of all miner revenue, which constitutes fees plus newly issued native units, represented as the US dollar amount earned if all native units were sold at the closing price on the same day.",
#                 "metric_id": "min.rev.usd",
#                 "minimum_interval": "1d",
#                 "name": "Mining Revenue (USD)",
#                 "source_attribution": [
#                     {
#                         "name": "Coinmetrics",
#                         "url": "https://coinmetrics.io"
#                     },
#                     {
#                         "name": "Kaiko",
#                         "url": "https://www.kaiko.com/"
#                     }
#                 ],
#                 "values_schema": {
#                     "revenue_usd": "The sum USD value of all miner revenue during the specified time interval"
#                 }
#             },
#             {
#                 "description": "It is well known that many exchanges conduct wash trading practices in order to inflate trading volume. They are incentivized to report inflated volumes in order to attract traders. \"Real Volume\" refers to the total volume on the exchanges that we believe with high level of confidence are free of wash trading activities. However, that does not necessarily mean that the volume reported by other exchanges is 100% wash trades. As such, the Messari \"Real Volume\" applies a penalty to these exchanges to discount the volume believed to come from wash trading activity. For more information, see our methodology page.",
#                 "metric_id": "real.vol",
#                 "minimum_interval": "1m",
#                 "name": "Real Volume",
#                 "source_attribution": [
#                     {
#                         "name": "Kaiko",
#                         "url": "https://www.kaiko.com/"
#                     }
#                 ],
#                 "values_schema": {
#                     "volume": "The total volume traded during the specified interval across all Messari method markets in US dollars"
#                 }
#             },
#             {
#                 "description": "The sum count of unique addresses holding at least 1,000,000 native units as of the end of that interval. Only native units are considered (e.g., an address with less than X ETH but with more than X in ERC-20 tokens would not be considered).",
#                 "metric_id": "addr.bal.1m.ntv.cnt",
#                 "minimum_interval": "1d",
#                 "name": "Address Count (Bal > 1M)",
#                 "role_restriction": [
#                     "pro",
#                     "enterprise"
#                 ],
#                 "source_attribution": [
#                     {
#                         "name": "Coinmetrics",
#                         "url": "https://coinmetrics.io"
#                     }
#                 ],
#                 "values_schema": {
#                     "addresses": "The sum count of unique addresses holding at least 1,000,000 native units as of the end of that interval. Only native units are considered (e.g., an address with less than X ETH but with more than X in ERC-20 tokens would not be considered)."
#                 }
#             },
#             {
#                 "description": "The sum of all native units being held in addresses whose balance was 1K native units or greater at the end of that interval. Only native units are considered (e.g., an address with less than X ETH but with more than X in ERC-20 tokens would not be considered).",
#                 "metric_id": "sply.addr.bal.1k.ntv",
#                 "minimum_interval": "1d",
#                 "name": "Supply from Addresses With Balance Above 1K Native Units",
#                 "role_restriction": [
#                     "pro",
#                     "enterprise"
#                 ],
#                 "source_attribution": [
#                     {
#                         "name": "Coinmetrics",
#                         "url": "https://coinmetrics.io"
#                     }
#                 ],
#                 "values_schema": {
#                     "supply_in_addr_above_bal_1k": "The sum of all native units being held in addresses whose balance was 1K native units or greater at the end of that interval. Only native units are considered (e.g., an address with less than X ETH but with more than X in ERC-20 tokens would not be considered)."
#                 }
#             },
#             {
#                 "description": "The sum count of transfers that interval. Transfers represent movements of native units from one ledger entity to another distinct ledger entity. Only transfers that are the result of a transaction and that have a positive (non-zero) value are counted.",
#                 "metric_id": "txn.tsfr.cnt",
#                 "minimum_interval": "1d",
#                 "name": "Transaction Transfer Count",
#                 "source_attribution": [
#                     {
#                         "name": "Coinmetrics",
#                         "url": "https://coinmetrics.io"
#                     }
#                 ],
#                 "values_schema": {
#                     "transfers_count": "The sum count of transfers that interval"
#                 }
#             },
#             {
#                 "description": "The sum USD value of the current supply. Also referred to as network value or market capitalization.",
#                 "metric_id": "mcap.out",
#                 "minimum_interval": "1d",
#                 "name": "Marketcap Outstanding",
#                 "source_attribution": [
#                     {
#                         "name": "Coinmetrics",
#                         "url": "https://coinmetrics.io"
#                     }
#                 ],
#                 "values_schema": {
#                     "marketcap_oustanding": "The sum USD value of the current supply. Also referred to as network value or market capitalization."
#                 }
#             },
#             {
#                 "description": "The sum of all fees paid to miners in native units. Fees do not include new issuance.",
#                 "metric_id": "fees.ntv",
#                 "minimum_interval": "1d",
#                 "name": "Total Fees",
#                 "source_attribution": [
#                     {
#                         "name": "Coinmetrics",
#                         "url": "https://coinmetrics.io"
#                     }
#                 ],
#                 "values_schema": {
#                     "fees_total": "The sum of all fees paid to miners in native units"
#                 }
#             },
#             {
#                 "description": "The USD value of the mean miner reward per estimated hash unit performed during the period, also known as hashprice. The unit of hashpower measurement depends on the protocol.",
#                 "metric_id": "hashrate.rev",
#                 "minimum_interval": "1d",
#                 "name": "Hash Revenue Per Second (USD)",
#                 "role_restriction": [
#                     "pro",
#                     "enterprise"
#                 ],
#                 "source_attribution": [
#                     {
#                         "name": "Coinmetrics",
#                         "url": "https://coinmetrics.io"
#                     }
#                 ],
#                 "values_schema": {
#                     "hash_revenue_per_second_usd": "The USD value of the mean miner reward per estimated hash unit performed during the period, also known as hashprice. The unit of hashpower measurement depends on the protocol."
#                 }
#             },
#             {
#                 "description": "The net native units value sent or withdrawn to/from Bitfinex that interval.",
#                 "metric_id": "exch.bitfinex.flow.net.ntv",
#                 "minimum_interval": "1d",
#                 "name": "Exchange Flow Net Bitfinex (Native Units)",
#                 "role_restriction": [
#                     "pro",
#                     "enterprise"
#                 ],
#                 "source_attribution": [
#                     {
#                         "name": "Coinmetrics",
#                         "url": "https://coinmetrics.io"
#                     }
#                 ],
#                 "values_schema": {
#                     "exchange_flow_net_bitfinex": "The net native units value sent or withdrawn to/from Bitfinex that interval."
#                 }
#             },
#             {
#                 "description": "The net USD value sent or withdrawn to/from Bitmex that interval.",
#                 "metric_id": "exch.bitmex.flow.net",
#                 "minimum_interval": "1d",
#                 "name": "Exchange Flow Net Bitmex (USD)",
#                 "role_restriction": [
#                     "pro",
#                     "enterprise"
#                 ],
#                 "source_attribution": [
#                     {
#                         "name": "Coinmetrics",
#                         "url": "https://coinmetrics.io"
#                     }
#                 ],
#                 "values_schema": {
#                     "exchange_flow_net_bitmex_usd": "The net USD value sent or withdrawn to/from Bitmex that interval."
#                 }
#             },
#             {
#                 "description": "The sum USD value of all miner revenue (fees plus newly issued native units) for all time from genesis up to the end of that interval.",
#                 "metric_id": "miner.rev.total",
#                 "minimum_interval": "1d",
#                 "name": "Mining Revenue Total USD",
#                 "role_restriction": [
#                     "pro",
#                     "enterprise"
#                 ],
#                 "source_attribution": [
#                     {
#                         "name": "Coinmetrics",
#                         "url": "https://coinmetrics.io"
#                     }
#                 ],
#                 "values_schema": {
#                     "miner_revenue_total": "The sum USD value of all miner revenue (fees plus newly issued native units) for all time from genesis up to the end of that interval."
#                 }
#             },
#             {
#                 "description": "The sum in US dollars withdrawn from Bitfinex that interval.",
#                 "metric_id": "exch.bitfinex.flow.out",
#                 "minimum_interval": "1d",
#                 "name": "Exchange Flow Out Bitfinex (USD)",
#                 "role_restriction": [
#                     "pro",
#                     "enterprise"
#                 ],
#                 "source_attribution": [
#                     {
#                         "name": "Coinmetrics",
#                         "url": "https://coinmetrics.io"
#                     }
#                 ],
#                 "values_schema": {
#                     "exchange_flow_out_bitfinex_usd": "The sum in native units withdrawn from Bitfinex that interval."
#                 }
#             },
#             {
#                 "description": "The sum of unique native units that transacted at least once in the trailing 4 years up to the end of that interval. Native units that transacted more than once are only counted once.",
#                 "metric_id": "sply.act.4y",
#                 "minimum_interval": "1d",
#                 "name": "4 Year Active Supply",
#                 "role_restriction": [
#                     "pro",
#                     "enterprise"
#                 ],
#                 "source_attribution": [
#                     {
#                         "name": "Coinmetrics",
#                         "url": "https://coinmetrics.io"
#                     }
#                 ],
#                 "values_schema": {
#                     "supply_active_4y": "The sum of unique native units that transacted at least once in the trailing 4 years up to the end of that interval. Native units that transacted more than once are only counted once."
#                 }
#             },
#             {
#                 "description": "The sum of all native units being held in addresses whose balance was $100 or greater at the end of that interval. Only native units are considered (e.g., an address with less than X ETH but with more than X in ERC-20 tokens would not be considered).",
#                 "metric_id": "sply.addr.bal.100",
#                 "minimum_interval": "1d",
#                 "name": "Supply from Addresses With Balance Above $100 USD",
#                 "role_restriction": [
#                     "pro",
#                     "enterprise"
#                 ],
#                 "source_attribution": [
#                     {
#                         "name": "Coinmetrics",
#                         "url": "https://coinmetrics.io"
#                     }
#                 ],
#                 "values_schema": {
#                     "supply_in_addr_above_bal_100_usd": "The sum of all native units being held in addresses whose balance was $100 or greater at the end of that interval. Only native units are considered (e.g., an address with less than X ETH but with more than X in ERC-20 tokens would not be considered)."
#                 }
#             },
#             {
#                 "description": "The sum count of unique addresses holding at least 1 native unit as of the end of that interval. Only native units are considered (e.g., an address with less than X ETH but with more than X in ERC-20 tokens would not be considered).",
#                 "metric_id": "addr.bal.1.ntv.cnt",
#                 "minimum_interval": "1d",
#                 "name": "Address Count (Bal > 1)",
#                 "role_restriction": [
#                     "pro",
#                     "enterprise"
#                 ],
#                 "source_attribution": [
#                     {
#                         "name": "Coinmetrics",
#                         "url": "https://coinmetrics.io"
#                     }
#                 ],
#                 "values_schema": {
#                     "addresses": "The sum count of unique addresses holding at least 1 native unit as of the end of that interval. Only native units are considered (e.g., an address with less than X ETH but with more than X in ERC-20 tokens would not be considered)."
#                 }
#             },
#             {
#                 "description": "The sum USD value of all native units transferred removing noise and certain artifacts.",
#                 "metric_id": "txn.tsfr.val.adj",
#                 "minimum_interval": "1d",
#                 "name": "Adjusted Transfer Value",
#                 "source_attribution": [
#                     {
#                         "name": "Coinmetrics",
#                         "url": "https://coinmetrics.io"
#                     }
#                 ],
#                 "values_schema": {
#                     "adjusted_transfer_value_usd": "The USD value of the sum of native units transferred removing noise and certain artifacts."
#                 }
#             },
#             {
#                 "description": "The sum USD value sent to Bitmex that interval.",
#                 "metric_id": "exch.bitmex.flow.in",
#                 "minimum_interval": "1d",
#                 "name": "Exchange Flow In Bitmex (USD)",
#                 "role_restriction": [
#                     "pro",
#                     "enterprise"
#                 ],
#                 "source_attribution": [
#                     {
#                         "name": "Coinmetrics",
#                         "url": "https://coinmetrics.io"
#                     }
#                 ],
#                 "values_schema": {
#                     "exchange_flow_in_bitmex_usd": "The sum USD value sent to Bitmex that interval."
#                 }
#             },
#             {
#                 "description": "The sum in native units sent to Bitmex that interval.",
#                 "metric_id": "exch.bitmex.flow.in.ntv",
#                 "minimum_interval": "1d",
#                 "name": "Exchange Flow In Bitmex (Native Units)",
#                 "role_restriction": [
#                     "pro",
#                     "enterprise"
#                 ],
#                 "source_attribution": [
#                     {
#                         "name": "Coinmetrics",
#                         "url": "https://coinmetrics.io"
#                     }
#                 ],
#                 "values_schema": {
#                     "exchange_flow_in_bitmex": "The sum in native units sent to Bitmex that interval."
#                 }
#             },
#             {
#                 "description": "The sum of all native units held by the richest 1% of addresses at the end of that interval.",
#                 "metric_id": "sply.top.1pct",
#                 "minimum_interval": "1d",
#                 "name": "Supply Top 1 Percent (Native Units)",
#                 "role_restriction": [
#                     "pro",
#                     "enterprise"
#                 ],
#                 "source_attribution": [
#                     {
#                         "name": "Coinmetrics",
#                         "url": "https://coinmetrics.io"
#                     }
#                 ],
#                 "values_schema": {
#                     "supply_top_1_percent": "The sum of all native units held by the richest 1% of addresses at the end of that interval."
#                 }
#             },
#             {
#                 "description": "The sum count of ERC-721 transfers in that interval. Only transfers between two distinct addresses are counted. ERC-165 is used to determine a contract\u2019s compliance with ERC-721.",
#                 "metric_id": "txn.tfr.erc721.cnt",
#                 "minimum_interval": "1d",
#                 "name": "ERC721 Transfer Transaction Count",
#                 "source_attribution": [
#                     {
#                         "name": "Coinmetrics",
#                         "url": "https://coinmetrics.io"
#                     }
#                 ],
#                 "values_schema": {
#                     "transaction_transfer_count_erc721": "The sum count of ERC-721 transfers in that interval. Only transfers between two distinct addresses are counted. ERC-165 is used to determine a contract\u2019s compliance with ERC-721."
#                 }
#             },
#             {
#                 "description": "The sum of all native unit balances last active at least 5 years ago that became active in this interval.",
#                 "metric_id": "sply.rvv.5y",
#                 "minimum_interval": "1d",
#                 "name": "5 Year Revived Supply",
#                 "role_restriction": [
#                     "pro",
#                     "enterprise"
#                 ],
#                 "source_attribution": [
#                     {
#                         "name": "Coinmetrics",
#                         "url": "https://coinmetrics.io"
#                     }
#                 ],
#                 "values_schema": {
#                     "supply_revived_5y": "The sum of all native unit balances last active at least 5 years ago that became active in this interval."
#                 }
#             },
#             {
#                 "description": "The median count of native units transferred per transfer (i.e., the median size of a transfer) between distinct addresses that interval.",
#                 "metric_id": "txn.tfr.val.med.ntv",
#                 "minimum_interval": "1d",
#                 "name": "Median Transfer Value (Native Units)",
#                 "source_attribution": [
#                     {
#                         "name": "Coinmetrics",
#                         "url": "https://coinmetrics.io"
#                     }
#                 ],
#                 "values_schema": {
#                     "transfer_value_median": "The median count of native units transferred per transfer (i.e., the median size of a transfer) between distinct addresses that interval."
#                 }
#             },
#             {
#                 "description": "The sum count of unique addresses holding at least one hundred dollars' worth of native units as of the end of that interval. Only native units are considered (e.g., an address with less than X ETH but with more than X in ERC-20 tokens would not be considered).",
#                 "metric_id": "addr.bal.100.cnt",
#                 "minimum_interval": "1d",
#                 "name": "Address Count (Bal > $100 USD)",
#                 "role_restriction": [
#                     "pro",
#                     "enterprise"
#                 ],
#                 "source_attribution": [
#                     {
#                         "name": "Coinmetrics",
#                         "url": "https://coinmetrics.io"
#                     }
#                 ],
#                 "values_schema": {
#                     "addresses": "The sum count of unique addresses holding at least one hundred dollars' worth of native units as of the end of that interval. Only native units are considered (e.g., an address with less than X ETH but with more than X in ERC-20 tokens would not be considered)."
#                 }
#             },
#             {
#                 "description": "The amount of the asset withdrawn from exchanges that interval, excluding exchange to exchange activity.",
#                 "metric_id": "exch.flow.out.ntv",
#                 "minimum_interval": "1d",
#                 "name": "Exchange Flow Out (Native Units)",
#                 "source_attribution": [
#                     {
#                         "name": "Coinmetrics",
#                         "url": "https://coinmetrics.io"
#                     }
#                 ],
#                 "values_schema": {
#                     "flow_out": "The amount of the asset withdrawn from exchanges that interval, excluding exchange to exchange activity."
#                 }
#             },
#             {
#                 "description": "The sum of all native units being held in addresses whose balance was $100K or greater at the end of that interval. Only native units are considered (e.g., an address with less than X ETH but with more than X in ERC-20 tokens would not be considered).",
#                 "metric_id": "sply.addr.bal.100k",
#                 "minimum_interval": "1d",
#                 "name": "Supply from Addresses With Balance Above 100K USD",
#                 "role_restriction": [
#                     "pro",
#                     "enterprise"
#                 ],
#                 "source_attribution": [
#                     {
#                         "name": "Coinmetrics",
#                         "url": "https://coinmetrics.io"
#                     }
#                 ],
#                 "values_schema": {
#                     "supply_in_addr_above_bal_100k_usd": "The sum of all native units being held in addresses whose balance was $100K or greater at the end of that interval. Only native units are considered (e.g., an address with less than X ETH but with more than X in ERC-20 tokens would not be considered)."
#                 }
#             },
#             {
#                 "description": "Volume weighted average price computed using Messari Methodology",
#                 "metric_id": "price",
#                 "minimum_interval": "1m",
#                 "name": "Price",
#                 "source_attribution": [
#                     {
#                         "name": "Kaiko",
#                         "url": "https://www.kaiko.com/"
#                     }
#                 ],
#                 "values_schema": {
#                     "close": "The price of the asset at the end of the specified interval in US dollars.",
#                     "high": "The highest price of the asset during the specified interval in US dollars.",
#                     "low": "The lowest price of the asset during the specified interval in US dollars",
#                     "open": "The price of the asset at the beginning of the specified interval in US dollars.",
#                     "volume": "The total volume traded during the specified interval across all Messari method markets in US dollars"
#                 }
#             },
#             {
#                 "description": "The number of active users on the asset's primary subreddit",
#                 "metric_id": "reddit.active.users",
#                 "minimum_interval": "1h",
#                 "name": "Reddit Active Users",
#                 "source_attribution": [
#                     {
#                         "name": "reddit",
#                         "url": "https://reddit.com/"
#                     }
#                 ],
#                 "values_schema": {
#                     "active_users": " The number of active users on the asset's primary subreddit"
#                 }
#             },
#             {
#                 "description": "The sum in native units held by Bitstamp at the end of that interval.",
#                 "metric_id": "exch.sply.bitstamp.ntv",
#                 "minimum_interval": "1d",
#                 "name": "Exchange Supply Bitstamp (Native Units)",
#                 "role_restriction": [
#                     "pro",
#                     "enterprise"
#                 ],
#                 "source_attribution": [
#                     {
#                         "name": "Coinmetrics",
#                         "url": "https://coinmetrics.io"
#                     }
#                 ],
#                 "values_schema": {
#                     "exchange_supply_bitstamp": "The sum in native units held by Bitstamp at the end of that interval."
#                 }
#             },
#             {
#                 "description": "The sum in native units held by Poloniex at the end of that interval.",
#                 "metric_id": "exch.sply.poloniex.ntv",
#                 "minimum_interval": "1d",
#                 "name": "Exchange Supply Poloniex (Native Units)",
#                 "role_restriction": [
#                     "pro",
#                     "enterprise"
#                 ],
#                 "source_attribution": [
#                     {
#                         "name": "Coinmetrics",
#                         "url": "https://coinmetrics.io"
#                     }
#                 ],
#                 "values_schema": {
#                     "exchange_supply_poloniex": "The sum in native units held by Poloniex at the end of that interval."
#                 }
#             },
#             {
#                 "description": "The sum count of unspent transaction outputs created on days where the closing price was lower than or equal to the closing price at the end of the period.",
#                 "metric_id": "utxo.prof.cnt",
#                 "minimum_interval": "1d",
#                 "name": "UTXO in Profit Count",
#                 "role_restriction": [
#                     "pro",
#                     "enterprise"
#                 ],
#                 "source_attribution": [
#                     {
#                         "name": "Coinmetrics",
#                         "url": "https://coinmetrics.io"
#                     }
#                 ],
#                 "values_schema": {
#                     "utxo_profit_count": "The sum count of unspent transaction outputs created on days where the closing price was lower than or equal to the closing price at the end of the period."
#                 }
#             },
#             {
#                 "description": "The mean absolute time (in seconds) between all the blocks created that interval.",
#                 "metric_id": "blk.int.avg",
#                 "minimum_interval": "1d",
#                 "name": "Block Interval Average",
#                 "role_restriction": [
#                     "pro",
#                     "enterprise"
#                 ],
#                 "source_attribution": [
#                     {
#                         "name": "Coinmetrics",
#                         "url": "https://coinmetrics.io"
#                     }
#                 ],
#                 "values_schema": {
#                     "block_interval_avg": "The mean absolute time (in seconds) between all the blocks created that interval."
#                 }
#             },
#             {
#                 "description": "The net USD value sent or withdrawn to/from Kraken that interval.",
#                 "metric_id": "exch.kraken.flow.net",
#                 "minimum_interval": "1d",
#                 "name": "Exchange Flow Net Kraken (USD)",
#                 "role_restriction": [
#                     "pro",
#                     "enterprise"
#                 ],
#                 "source_attribution": [
#                     {
#                         "name": "Coinmetrics",
#                         "url": "https://coinmetrics.io"
#                     }
#                 ],
#                 "values_schema": {
#                     "exchange_flow_net_kraken_usd": "The net USD value sent or withdrawn to/from Kraken that interval."
#                 }
#             },
#             {
#                 "description": "The sum in native units withdrawn from Kraken that interval.",
#                 "metric_id": "exch.kraken.flow.out.ntv",
#                 "minimum_interval": "1d",
#                 "name": "Exchange Flow Out Kraken (Native Units)",
#                 "role_restriction": [
#                     "pro",
#                     "enterprise"
#                 ],
#                 "source_attribution": [
#                     {
#                         "name": "Coinmetrics",
#                         "url": "https://coinmetrics.io"
#                     }
#                 ],
#                 "values_schema": {
#                     "exchange_flow_out_kraken": "The sum in native units withdrawn from Kraken that interval."
#                 }
#             },
#             {
#                 "description": "The sum of unique native units that transacted at least once in the trailing 180 days up to the end of that interval. Native units that transacted more than once are only counted once.",
#                 "metric_id": "sply.act.180d",
#                 "minimum_interval": "1d",
#                 "name": "180 Day Active Supply",
#                 "role_restriction": [
#                     "pro",
#                     "enterprise"
#                 ],
#                 "source_attribution": [
#                     {
#                         "name": "Coinmetrics",
#                         "url": "https://coinmetrics.io"
#                     }
#                 ],
#                 "values_schema": {
#                     "supply_active_180d": "The sum of unique native units that transacted at least once in the trailing 180 days up to the end of that interval. Native units that transacted more than once are only counted once."
#                 }
#             },
#             {
#                 "description": "The mean gas used (i.e., paid) across all transactions that interval.",
#                 "metric_id": "txn.gas.avg",
#                 "minimum_interval": "1d",
#                 "name": "Average Gas Used Each Transaction",
#                 "role_restriction": [
#                     "pro",
#                     "enterprise"
#                 ],
#                 "source_attribution": [
#                     {
#                         "name": "Coinmetrics",
#                         "url": "https://coinmetrics.io"
#                     }
#                 ],
#                 "values_schema": {
#                     "transaction_gas_avg": "The mean gas used (i.e., paid) across all transactions that interval."
#                 }
#             },
#             {
#                 "description": "The sum of unique native units that transacted at least once in the trailing 1 days up to the end of that interval. Native units that transacted more than once are only counted once.",
#                 "metric_id": "sply.act.1d",
#                 "minimum_interval": "1d",
#                 "name": "1 Day Active Supply",
#                 "role_restriction": [
#                     "pro",
#                     "enterprise"
#                 ],
#                 "source_attribution": [
#                     {
#                         "name": "Coinmetrics",
#                         "url": "https://coinmetrics.io"
#                     }
#                 ],
#                 "values_schema": {
#                     "supply_active_1d": "The sum of unique native units that transacted at least once in the trailing 1 days up to the end of that interval. Native units that transacted more than once are only counted once."
#                 }
#             },
#             {
#                 "description": "The sum of all native unit balances last active at least 2 years ago that became active in this interval.",
#                 "metric_id": "sply.rvv.2y",
#                 "minimum_interval": "1d",
#                 "name": "2 Year Revived Supply",
# ...
#                 "metric_id": "exch.sply",
#                 "minimum_interval": "1d",
#                 "name": "Exchange Supply",
#                 "source_attribution": [
#                     {
#                         "name": "Coinmetrics",
#                         "url": "https://coinmetrics.io"
#                     }
#                 ],
#                 "values_schema": {
#                     "supply_usd": "The sum of all native units held in hot or cold exchange wallets that interval."
#                 }
#             },
#             {
#                 "description": "The net native units value sent or withdrawn to/from Poloniex that interval.",
#                 "metric_id": "exch.poloniex.flow.net.ntv",
#                 "minimum_interval": "1d",
#                 "name": "Exchange Flow Net Poloniex (Native Units)",
#                 "role_restriction": [
#                     "pro",
#                     "enterprise"
#                 ],
#                 "source_attribution": [
#                     {
#                         "name": "Coinmetrics",
#                         "url": "https://coinmetrics.io"
#                     }
#                 ],
#                 "values_schema": {
#                     "exchange_flow_net_poloniex": "The net native units value sent or withdrawn to/from Poloniex that interval."
#                 }
#             },
#             {
#                 "description": "The sum count of transactions that resulted in any ERC-721 activity in that interval. Only transfers between two distinct addresses are counted. ERC-165 is used to determine a contract\u2019s compliance with ERC-721. Only Transfer or Approval events are counted as activity. If a transaction results in more than 1 transfer or approval, it\u2019s only counted once.",
#                 "metric_id": "txn.erc721.cnt",
#                 "minimum_interval": "1d",
#                 "name": "ERC721 Transaction Count",
#                 "role_restriction": [
#                     "pro",
#                     "enterprise"
#                 ],
#                 "source_attribution": [
#                     {
#                         "name": "Coinmetrics",
#                         "url": "https://coinmetrics.io"
#                     }
#                 ],
#                 "values_schema": {
#                     "transaction_count_erc721": "The sum count of transactions that resulted in any ERC-721 activity in that interval. Only transfers between two distinct addresses are counted. ERC-165 is used to determine a contract\u2019s compliance with ERC-721. Only Transfer or Approval events are counted as activity. If a transaction results in more than 1 transfer or approval, it\u2019s only counted once."
#                 }
#             },
#             {
#                 "description": "The sum of all native units being held in addresses whose balance was 100 native units or greater at the end of that interval. Only native units are considered (e.g., an address with less than X ETH but with more than X in ERC-20 tokens would not be considered).",
#                 "metric_id": "sply.addr.bal.100.ntv",
#                 "minimum_interval": "1d",
#                 "name": "Supply from Addresses With Balance Above 100 Native Units",
#                 "role_restriction": [
#                     "pro",
#                     "enterprise"
#                 ],
#                 "source_attribution": [
#                     {
#                         "name": "Coinmetrics",
#                         "url": "https://coinmetrics.io"
#                     }
#                 ],
#                 "values_schema": {
#                     "supply_in_addr_above_bal_100": "The sum of all native units being held in addresses whose balance was 100 native units or greater at the end of that interval. Only native units are considered (e.g., an address with less than X ETH but with more than X in ERC-20 tokens would not be considered)."
#                 }
#             },
#             {
#                 "description": "The sum count of contract calls successfully executed across all transactions in that interval. A contract call is the invocation of a contract\u2019s code by another contract or non-contract address. Only successful executions are taken into account.",
#                 "metric_id": "txn.cont.call.succ.cnt",
#                 "minimum_interval": "1d",
#                 "name": "Contract Call Successes",
#                 "role_restriction": [
#                     "pro",
#                     "enterprise"
#                 ],
#                 "source_attribution": [
#                     {
#                         "name": "Coinmetrics",
#                         "url": "https://coinmetrics.io"
#                     }
#                 ],
#                 "values_schema": {
#                     "transaction_count_contract_call_successes": "The sum count of contract calls successfully executed across all transactions in that interval. A contract call is the invocation of a contract\u2019s code by another contract or non-contract address. Only successful executions are taken into account."
#                 }
#             },
#             {
#                 "description": "The circulating supply acknowledges that tokens may be held by projects/foundations which have no intent to sell down their positions, but which have not locked up supply in a formal contract. Thus, circulating supply does not include known project treasury holdings (which can be significant). Note that an investor must carefully consider both liquid and circulating supplies when evaluating an asset, and the two can vary significantly. A risk of depending entirely on circulating supply is that the number can change dramatically based on discretionary sales from project treasuries.",
#                 "metric_id": "cg.sply.circ",
#                 "minimum_interval": "1d",
#                 "name": "Circulating Supply",
#                 "source_attribution": [
#                     {
#                         "name": "CoinGecko",
#                         "url": "https://coingecko.com"
#                     }
#                 ],
#                 "values_schema": {
#                     "circulating_supply": "The circulating supply of the asset is the total supply of the asset not locked into legal contracts, smart contracts, or held in treasury wallets."
#                 }
#             },
#             {
#                 "description": "The sum in native units held by Huobi at the end of that interval.",
#                 "metric_id": "exch.sply.huobi.ntv",
#                 "minimum_interval": "1d",
#                 "name": "Exchange Supply Huobi (Native Units)",
#                 "role_restriction": [
#                     "pro",
#                     "enterprise"
#                 ],
#                 "source_attribution": [
#                     {
#                         "name": "Coinmetrics",
#                         "url": "https://coinmetrics.io"
#                     }
#                 ],
#                 "values_schema": {
#                     "exchange_supply_bitfinex": "The sum in native units held by Huobi at the end of that interval."
#                 }
#             },
#             {
#                 "description": "The sum USD value withdrawn from exchanges that interval, excluding exchange to exchange activity.",
#                 "metric_id": "exch.flow.out.usd",
#                 "minimum_interval": "1d",
#                 "name": "Exchange Flow Out (USD)",
#                 "source_attribution": [
#                     {
#                         "name": "Coinmetrics",
#                         "url": "https://coinmetrics.io"
#                     }
#                 ],
#                 "values_schema": {
#                     "flow_out_usd": "The sum USD value withdrawn from exchanges that interval, excluding exchange to exchange activity."
#                 }
#             },
#             {
#                 "description": "The sum of the balances of all mining entities. A mining entity is defined as an address that has been credited from a transaction debiting the 'FEES' or 'ISSUANCE' accounts.",
#                 "metric_id": "miner.sply.ntv",
#                 "minimum_interval": "1d",
#                 "name": "Miner Supply",
#                 "role_restriction": [
#                     "pro",
#                     "enterprise"
#                 ],
#                 "source_attribution": [
#                     {
#                         "name": "Coinmetrics",
#                         "url": "https://coinmetrics.io"
#                     }
#                 ],
#                 "values_schema": {
#                     "miner_supply": "The sum of the balances of all mining entities. A mining entity is defined as an address that has been credited from a transaction debiting the 'FEES' or 'ISSUANCE' accounts."
#                 }
#             },
#             {
#                 "description": "The net USD value sent or withdrawn to/from Gemini that interval.",
#                 "metric_id": "exch.gemini.flow.net",
#                 "minimum_interval": "1d",
#                 "name": "Exchange Flow Net Gemini (USD)",
#                 "role_restriction": [
#                     "pro",
#                     "enterprise"
#                 ],
#                 "source_attribution": [
#                     {
#                         "name": "Coinmetrics",
#                         "url": "https://coinmetrics.io"
#                     }
#                 ],
#                 "values_schema": {
#                     "exchange_flow_net_gemini_usd": "The net USD value sent or withdrawn to/from Gemini that interval."
#                 }
#             },
#             {
#                 "description": "The sum in native units withdrawn from Bitmex that interval.",
#                 "metric_id": "exch.bitmex.flow.out",
#                 "minimum_interval": "1d",
#                 "name": "Exchange Flow Out Bitmex (USD)",
#                 "role_restriction": [
#                     "pro",
#                     "enterprise"
#                 ],
#                 "source_attribution": [
#                     {
#                         "name": "Coinmetrics",
#                         "url": "https://coinmetrics.io"
#                     }
#                 ],
#                 "values_schema": {
#                     "exchange_flow_out_bitmex_usd": "The sum in native units withdrawn from Bitmex that interval."
#                 }
#             },
#             {
#                 "description": "The sum USD value of native units transferred divided by the count of transfers (i.e., the mean \"size\" in USD of a transfer).",
#                 "metric_id": "txn.tsfr.val.avg",
#                 "minimum_interval": "1d",
#                 "name": "Average Transfer Value (USD)",
#                 "source_attribution": [
#                     {
#                         "name": "Coinmetrics",
#                         "url": "https://coinmetrics.io"
#                     }
#                 ],
#                 "values_schema": {
#                     "average_transfer_value_usd": "The sum USD value of native units transferred divided by the count of transfers that interval."
#                 }
#             },
#             {
#                 "description": "The sum count of unique addresses holding at least ten dollars' worth of native units as of the end of that interval. Only native units are considered (e.g., an address with less than X ETH but with more than X in ERC-20 tokens would not be considered).",
#                 "metric_id": "addr.bal.10.cnt",
#                 "minimum_interval": "1d",
#                 "name": "Address Count (Bal > $10 USD)",
#                 "role_restriction": [
#                     "pro",
#                     "enterprise"
#                 ],
#                 "source_attribution": [
#                     {
#                         "name": "Coinmetrics",
#                         "url": "https://coinmetrics.io"
#                     }
#                 ],
#                 "values_schema": {
#                     "addresses": "The sum count of unique addresses holding at least ten dollars' worth of native units as of the end of that interval. Only native units are considered (e.g., an address with less than X ETH but with more than X in ERC-20 tokens would not be considered)."
#                 }
#             },
#             {
#                 "description": "The count of blocks from the genesis (first) block to the last block of that interval on the main chain.",
#                 "metric_id": "blk.hgt",
#                 "minimum_interval": "1d",
#                 "name": "Block Height",
#                 "role_restriction": [
#                     "pro",
#                     "enterprise"
#                 ],
#                 "source_attribution": [
#                     {
#                         "name": "Coinmetrics",
#                         "url": "https://coinmetrics.io"
#                     }
#                 ],
#                 "values_schema": {
#                     "block_height": "The count of blocks from the genesis (first) block to the last block of that interval on the main chain."
#                 }
#             },
#             {
#                 "description": "The amount of the asset sent to exchanges that interval, excluding exchange to exchange activity.",
#                 "metric_id": "exch.flow.in.ntv",
#                 "minimum_interval": "1d",
#                 "name": "Exchange Flow In (Native Units)",
#                 "source_attribution": [
#                     {
#                         "name": "Coinmetrics",
#                         "url": "https://coinmetrics.io"
#                     }
#                 ],
#                 "values_schema": {
#                     "flow_in": "The amount of the asset sent to exchanges that interval, excluding exchange to exchange activity."
#                 }
#             },
#             {
#                 "description": "The sum of unique native units that transacted at least once in the trailing 30 days up to the end of that interval. Native units that transacted more than once are only counted once.",
#                 "metric_id": "sply.act.30d",
#                 "minimum_interval": "1d",
#                 "name": "30 Day Active Supply",
#                 "role_restriction": [
#                     "pro",
#                     "enterprise"
#                 ],
#                 "source_attribution": [
#                     {
#                         "name": "Coinmetrics",
#                         "url": "https://coinmetrics.io"
#                     }
#                 ],
#                 "values_schema": {
#                     "supply_active_30d": "The sum of unique native units that transacted at least once in the trailing 30 days up to the end of that interval. Native units that transacted more than once are only counted once."
#                 }
#             },
#             {
#                 "description": "The sum of all native units being held in addresses whose balance was $10 or greater at the end of that interval. Only native units are considered (e.g., an address with less than X ETH but with more than X in ERC-20 tokens would not be considered).",
#                 "metric_id": "sply.addr.bal.10",
#                 "minimum_interval": "1d",
#                 "name": "Supply from Addresses With Balance Above $10 USD",
#                 "role_restriction": [
#                     "pro",
#                     "enterprise"
#                 ],
#                 "source_attribution": [
#                     {
#                         "name": "Coinmetrics",
#                         "url": "https://coinmetrics.io"
#                     }
#                 ],
#                 "values_schema": {
#                     "supply_in_addr_above_bal_10_usd": "The sum of all native units being held in addresses whose balance was $10 or greater at the end of that interval. Only native units are considered (e.g., an address with less than X ETH but with more than X in ERC-20 tokens would not be considered)."
#                 }
#             }
#         ]
#     },
#     "status": {
#         "elapsed": 1,
#         "timestamp": "2021-09-08T04:24:52.887250944Z"
#     }
# }

# %%
merge_df = uni.merge(yfi, left_index = True, right_index = True)
print(merge_df.head())
# Out:
#                  uni           yfi
# timestamp
# 2021-01-01  4.746491  21898.581377
# 2021-01-02  4.859523  21467.056191
# 2021-01-03  5.520508  23903.585935
# 2021-01-04  5.425185  23391.127028
# 2021-01-05  6.271046  23810.774761

# %%
df_list = [uni,yfi]
merge2 = reduce(lambda df1,df2: pd.merge(df1,df2, left_index = True, right_index = True), df_list)
print(merge2.head())
# Out:
#                  uni           yfi
# timestamp
# 2021-01-01  4.746491  21898.581377
# 2021-01-02  4.859523  21467.056191
# 2021-01-03  5.520508  23903.585935
# 2021-01-04  5.425185  23391.127028
# 2021-01-05  6.271046  23810.774761

# %%
messari_any_url = "https://data.messari.io/api/v1/assets/uni/metrics/reddit.active.users/time-series?start=2021-01-01&end=2021-02-01&interval=1d"
response3 = requests.get(messari_any_url)
print(response3.status_code)
data3 = response3.json()
dumps3 = json.dumps(data3, sort_keys=True, indent=4)
print(dumps3)
# Out:
# 200
# {
#     "data": {
#         "parameters": {
#             "asset_id": "1d51479d-68f6-4886-8644-2a55ea9007bf",
#             "asset_key": "uni",
#             "columns": [
#                 "timestamp",
#                 "active_users"
#             ],
#             "end": "2021-02-01T00:00:00Z",
#             "format": "json",
#             "interval": "1d",
#             "order": "ascending",
#             "start": "2021-01-01T00:00:00Z",
#             "timestamp_format": "unix-milliseconds"
#         },
#         "schema": {
#             "description": "The number of active users on the asset's primary subreddit",
#             "metric_id": "reddit.active.users",
#             "minimum_interval": "1h",
#             "name": "Reddit Active Users",
#             "source_attribution": [
#                 {
#                     "name": "reddit",
#                     "url": "https://reddit.com/"
#                 }
#             ],
#             "values_schema": {
#                 "active_users": " The number of active users on the asset's primary subreddit",
#                 "timestamp": "Timestamp in milliseconds since the epoch (1 January 1970 00:00:00 UTC)"
#             }
#         },
#         "values": [
#             [
#                 1609459200000,
#                 129
#             ],
#             [
#                 1609545600000,
#                 140
#             ],
#             [
#                 1609632000000,
#                 212
#             ],
#             [
#                 1609718400000,
#                 226
#             ],
#             [
#                 1609804800000,
#                 211
#             ],
#             [
#                 1609891200000,
#                 134
#             ],
#             [
#                 1609977600000,
#                 131
#             ],
#             [
#                 1610064000000,
#                 117
#             ],
#             [
#                 1610150400000,
#                 156
#             ],
#             [
#                 1610236800000,
#                 94
#             ],
#             [
#                 1610323200000,
#                 114
#             ],
#             [
#                 1610409600000,
#                 125
#             ],
#             [
#                 1610496000000,
#                 127
#             ],
#             [
#                 1610582400000,
#                 149
#             ],
#             [
#                 1610668800000,
#                 107
#             ],
#             [
#                 1610755200000,
#                 162
#             ],
#             [
#                 1610841600000,
#                 151
#             ],
#             [
#                 1610928000000,
#                 140
#             ],
#             [
#                 1611014400000,
#                 140
#             ],
#             [
#                 1611100800000,
#                 124
#             ],
#             [
#                 1611187200000,
#                 123
#             ],
#             [
#                 1611273600000,
#                 130
#             ],
#             [
#                 1611360000000,
#                 160
#             ],
#             [
#                 1611446400000,
#                 272
#             ],
#             [
#                 1611532800000,
#                 187
#             ],
#             [
#                 1611619200000,
#                 367
#             ],
#             [
#                 1611705600000,
#                 304
#             ],
#             [
#                 1611792000000,
#                 251
#             ],
#             [
#                 1611878400000,
#                 229
#             ],
#             [
#                 1611964800000,
#                 448
#             ],
#             [
#                 1612051200000,
#                 359
#             ],
#             [
#                 1612137600000,
#                 592
#             ]
#         ]
#     },
#     "status": {
#         "elapsed": 488,
#         "timestamp": "2021-09-08T06:12:07.549764296Z"
#     }
# }

# %%
info3 = json.loads(dumps3)
data_df3 =json_normalize(info3['data'], record_path = ['values'])
#print(info3)
schema = list(info3['data']['schema']['values_schema'].keys())
data_df3.columns =schema.reverse()
print(type(schema))
print(schema)
print(data_df3.head())
# Out:
# <class 'list'>
# ['active_users', 'timestamp']
#     active_users  timestamp
# 0  1609459200000        129
# 1  1609545600000        140
# 2  1609632000000        212
# 3  1609718400000        226
# 4  1609804800000        211
